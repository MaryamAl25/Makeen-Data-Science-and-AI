# %%
import pandas as pd
import numpy as np

# %%
# -----------------------------
# 1. Open the article page
# -----------------------------
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://omannews.gov.om/topics/en/132/show/125517/ona")
wait = WebDriverWait(driver, 15)

# -----------------------------
# 2. Extract the headline
# -----------------------------
try:
    headline_elem = wait.until(
        EC.presence_of_element_located((By.TAG_NAME, "h1"))
    )
    headline = headline_elem.text
except:
    headline = "N/A"

# -----------------------------
# 3. Extract the published time (XPath: p[1])
# -----------------------------
time_xpath = '//*[@id="contentWrapper"]/div[3]/div[1]/div/div/div[1]/article/div/p[1]'

try:
    published_time_elem = wait.until(
        EC.presence_of_element_located((By.XPATH, time_xpath))
    )
    published_time = published_time_elem.text
except:
    published_time = "N/A"

# -----------------------------
# 4. Extract full article text (all <p> tags)
# -----------------------------
paragraphs = driver.find_elements(By.XPATH, '//*[@id="contentWrapper"]//article//p')
article_text = "\n".join([p.text for p in paragraphs if p.text.strip() != ""])

# -----------------------------
# 5. Close browser
# -----------------------------
driver.quit()

# -----------------------------
# 6. Save to Excel
# -----------------------------
wb = Workbook()
ws = wb.active
ws.title = "ONA Article"

# Header row
ws.append(["Headline", "Published Time", "Article Text"])

# Data row
ws.append([headline, published_time, article_text.strip()])

file_name = "ona_article_p1_safe.xlsx"
wb.save(file_name)

print(f"Saved to {file_name}")
# Out:
# Saved to ona_article_p1_safe.xlsx

# %%
df = pd.read_excel('ona_article_p1.xlsx')
df = pd.DataFrame(df)
df
# Out:
#   Headline                                     Published Time  \
# 0     NEWS  Winners of Green Innovation Hackathon Announce...
#
#                                         Article Text
# 0  Winners of Green Innovation Hackathon Announce...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Send GET request to the page
url = "https://rssfeeds.timesofoman.com/index.php/category/oman/"
response = requests.get(url)

# Parse HTML content
soup = BeautifulSoup(response.text, "html.parser")

data = []  # List to store all extracted results

# Find all article sections
articles = soup.find_all("article", class_="post")

for art in articles:
    
    # ------------------ IMAGE EXTRACTION ------------------
    img_tag = art.find("img")  # Locate the <img> tag inside the article
    img_url = None
    img_alt = None

    if img_tag:
        img_url = img_tag.get("src") or img_tag.get("data-src") or img_tag.get("data-lazy-src")  # Image link
        img_alt = img_tag.get("data-alt") or img_tag.get("alt")  # Alternative text

        # Fix links that start with //
        if img_url.startswith("//"):
            img_url = "https:" + img_url

    # Fix links that start with /
    if img_url and img_url.startswith("/"):
        img_url = "https://shabiba.eu-central-1.linodeobjects.com" + img_url

    # ------------------ DATE EXTRACTION ------------------
    date_tag = art.find("h3", class_="date")  # Find date container
    date_text = date_tag.get_text(strip=True) if date_tag else None  # Extract date text

    # ------------------ TITLE + ARTICLE URL ------------------
    title_tag = art.find("h2", class_="post-title")  # Article title section
    if title_tag:
        link = title_tag.find("a")  # Find anchor tag inside the title
        title = link.get_text(strip=True)  # Extract title text
        article_url = link.get("href")  # Get article link

        # Fix relative link
        if article_url.startswith("/"):
            article_url = "https://timesofoman.com" + article_url
    else:
        title = None
        article_url = None

    # ------------------ SUMMARY TEXT ------------------
    summary = art.find("div", class_="post-text")  # Find summary container
    summary_text = summary.get_text(strip=True) if summary else None  # Extract summary text

    # ------------------ STORE DATA ------------------
    data.append({
        "Date": date_text,
        "Title": title,
        "Summary": summary_text,
        "Article_URL": article_url,
        "Image_URL": img_url,
        "Image_Alt": img_alt
    })

# Convert list to DataFrame
df = pd.DataFrame(data)

# Save results to Excel file
df.to_excel("oman_news_images.xlsx", index=False)

# %%
df = pd.read_excel('oman_news_images.xlsx')
df = pd.DataFrame(df)
df
# Out:
#                                   Date  \
# 0     Sunday 16/November/2025 11:02 AM
# 1     Sunday 16/November/2025 10:28 AM
# 2   Saturday 15/November/2025 15:41 PM
# 3   Saturday 15/November/2025 15:30 PM
# 4   Saturday 15/November/2025 14:06 PM
# 5     Friday 14/November/2025 16:03 PM
# 6     Friday 14/November/2025 13:07 PM
# 7     Friday 14/November/2025 07:53 AM
# 8     Friday 14/November/2025 06:33 AM
# 9   Thursday 13/November/2025 19:35 PM
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
#
#                                                 Title  \
# 0   Oman Airports becomes world’s first to launch ...
# 1   His Majesty confers Oman’s highest civilian ho...
# 2   Sayyid Badr receives phone call from Deputy Pr...
# 3     Oman makes remarkable progress in digital field
# 4   Dhofar Governorate is moving forward under Ren...
# 5   Abundance of Winter crops at Tawi Al-Hara Mark...
# 6   Environment Authority conducts study to analys...
# 7   Foreign Minister discusses regional developmen...
# 8   Oman introduces cultural visa to facilitate kn...
# 9   Oman celebrates international day against illi...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#                                               Summary  \
# 0   Muscat: Oman Airports has announced that it ha...
# 1   Muscat: His Majesty Sultan Haitham bin Tarik c...
# 2   Muscat: Foreign Minister Sayyid Badr Hamad Al ...
# 3   Muscat: The Sultanate of Oman is making remark...
# 4   Salalah: The Dhofar Governorate is moving forw...
# 5   Rustaq: The Tawi Al-Hara market in Rustaq Gove...
# 6   Muscat: The Environment Authority has conducte...
# 7   Muscat: Foreign Minister Sayyid Badr Albusaidi...
# 8   Muscat: The Sultanate of Oman has introduced t...
# 9   Muscat: The Sultanate of Oman is joining the g...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#                                           Article_URL  \
# 0   https://timesofoman.com/article/165086-oman-ai...
# 1   https://timesofoman.com/article/165083-his-maj...
# 2   https://timesofoman.com/article/165062-sayyid-...
# 3   https://timesofoman.com/article/165061-oman-ma...
# 4   https://timesofoman.com/article/165058-dhofar-...
# 5   https://timesofoman.com/article/165043-abundan...
# 6   https://timesofoman.com/article/165036-environ...
# 7   https://timesofoman.com/article/165030-foreign...
# 8   https://timesofoman.com/article/165029-oman-in...
# 9   https://timesofoman.com/article/165017-oman-ce...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#                                             Image_URL  \
# 0   https://shabiba.eu-central-1.linodeobjects.com...
# 1   https://shabiba.eu-central-1.linodeobjects.com...
# 2   https://shabiba.eu-central-1.linodeobjects.com...
# 3   https://shabiba.eu-central-1.linodeobjects.com...
# 4   https://shabiba.eu-central-1.linodeobjects.com...
# 5   https://shabiba.eu-central-1.linodeobjects.com...
# 6   https://shabiba.eu-central-1.linodeobjects.com...
# 7   https://shabiba.eu-central-1.linodeobjects.com...
# 8   https://shabiba.eu-central-1.linodeobjects.com...
# 9   https://shabiba.eu-central-1.linodeobjects.com...
# 10  https://shabiba.eu-central-1.linodeobjects.com...
# 11  https://shabiba.eu-central-1.linodeobjects.com...
# 12  https://shabiba.eu-central-1.linodeobjects.com...
# 13  https://shabiba.eu-central-1.linodeobjects.com...
#
#                                             Image_Alt
# 0   Oman Airports becomes world’s first to launch ...
# 1   His Majesty confers Oman’s highest civilian ho...
# 2   Sayyid Badr receives phone call from Deputy Pr...
# 3     Oman makes remarkable progress in digital field
# 4   Dhofar Governorate is moving forward under Ren...
# 5   Abundance of Winter crops at Tawi Al-Hara Mark...
# 6   Environment Authority conducts study to analys...
# 7   Foreign Minister discusses regional developmen...
# 8   Oman introduces cultural visa to facilitate kn...
# 9   Oman celebrates international day against illi...
# 10  China's rare earth monopoly threatens global c...
# 11  Oman Airports becomes world’s first to launch ...
# 12  UAE: IAF contingent comprising Suryakiran Aero...
# 13  India-France defence chiefs hold talks to adva...
