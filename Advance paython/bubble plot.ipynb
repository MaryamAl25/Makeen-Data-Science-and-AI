# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook"

# %%
df = pd.read_csv("data_science_student_marks.csv")
df
# Out:
#      student_id     location  age  sql_marks  excel_marks  python_marks  \
# 0             4       Sydney   24         95           99            87
# 1             5        Tokyo   24         99           95            89
# 2             6       Berlin   22         72           70            99
# 3             7       London   23         97           90            74
# 4             8        Tokyo   22         91           71            79
# ..          ...          ...  ...        ...          ...           ...
# 492         496     New York   23         71           92            98
# 493         497  Los Angeles   20         90          100            90
# 494         498        Paris   22         78           80            78
# 495         499  Los Angeles   21         96           93            78
# 496         500       London   22         85           87            93
#
#      power_bi_marks  english_marks
# 0                82             75
# 1                86             82
# 2                79             77
# 3                72             85
# 4                80             75
# ..              ...            ...
# 492              78             88
# 493              78             73
# 494              71             70
# 495              78             82
# 496              70             86
#
# [497 rows x 8 columns]

# %%
df = pd.DataFrame(df)
df
# Out:
#      student_id     location  age  sql_marks  excel_marks  python_marks  \
# 0             4       Sydney   24         95           99            87
# 1             5        Tokyo   24         99           95            89
# 2             6       Berlin   22         72           70            99
# 3             7       London   23         97           90            74
# 4             8        Tokyo   22         91           71            79
# ..          ...          ...  ...        ...          ...           ...
# 492         496     New York   23         71           92            98
# 493         497  Los Angeles   20         90          100            90
# 494         498        Paris   22         78           80            78
# 495         499  Los Angeles   21         96           93            78
# 496         500       London   22         85           87            93
#
#      power_bi_marks  english_marks
# 0                82             75
# 1                86             82
# 2                79             77
# 3                72             85
# 4                80             75
# ..              ...            ...
# 492              78             88
# 493              78             73
# 494              71             70
# 495              78             82
# 496              70             86
#
# [497 rows x 8 columns]

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import plotly.express as px
import plotly.io as pio

#Group by city and calculate average marks
df_city = df.groupby("location", as_index=False).agg({
    "sql_marks": "mean",
    "excel_marks": "mean",
    "python_marks": "mean",
    "power_bi_marks": "mean",
    "english_marks": "mean"
})

#Calculate the overall average of all marks for each city
df_city["avg_marks"] = df_city[[
    "sql_marks", "excel_marks", "python_marks", "power_bi_marks", "english_marks"
]].mean(axis=1)

# 🔹 Round all numeric columns to 2 decimal places
df_city = df_city.round({
    "sql_marks": 2,
    "excel_marks": 2,
    "python_marks": 2,
    "power_bi_marks": 2,
    "english_marks": 2,
    "avg_marks": 2
})

#Get latitude and longitude for each city (quick version)
geolocator = Nominatim(user_agent="geoapi")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=0.2)

df_city["geo"] = df_city["location"].apply(geocode)
df_city["lat"] = df_city["geo"].apply(lambda loc: loc.latitude if loc else None)
df_city["lon"] = df_city["geo"].apply(lambda loc: loc.longitude if loc else None)
df_city.drop(columns=["geo"], inplace=True)

#Create the bubble map
pio.renderers.default = "notebook_connected"  # for Jupyter

fig = px.scatter_geo(
    df_city,
    lat="lat",
    lon="lon",
    color="avg_marks",                # color = average of all marks
    hover_name="location",
    hover_data={
        "avg_marks": True,
        "sql_marks": True,
        "excel_marks": True,
        "python_marks": True,
        "power_bi_marks": True,
        "english_marks": True,
        "lat": False,
        "lon": False
    },
    title="Average Student Performance by City",
    size=[15]*len(df_city),           # fixed bubble size
    projection="natural earth",
    color_continuous_scale="Viridis"  # color gradient (blue→green→yellow)
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="674b42ab-a805-4933-94dd-37cca2b25247" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("674b42ab-a805-4933-94dd-37cca2b25247")) {                    Plotly.newPlot(                        "674b42ab-a805-4933-94dd-37cca2b25247",                        [{"customdata":{"dtype":"f8","bdata":"\u002fV5MTnoQsBHTJpQ0h5iQHsUrkfhWlVA7FG4HoVLVUD2KFyPwjVVQOF6FK5HsVVAKVyPwvVYVUDNzMzMzDxVQFk4pKw6W0RA2dGTjWKAUsD2KFyPwiVVQLgehetRyFRAKVyPwvVoVUC4HoXrUVhVQDMzMzMzA1VAAAAAAAAwVUCFLwIZ8G1IQHgI46dxjwJACtejcD1KVUApXI\u002fC9ahVQHE9CtejYFVAUrgehesRVUC4HoXrUUhVQB+F61G4DlVAA5B\u002fC1fvQMAgiOJEquZiQI\u002fC9ShcX1VAmpmZmZkpVUAfhetRuH5VQFK4HoXrgVVAUrgeheuBVUDhehSuRzFVQNC7DFqj1kFAz0JM03F4YUA9CtejcC1VQB+F61G4LlVAzczMzMz8VEApXI\u002fC9WhVQB+F61G4rlRAAAAAAACgVUBqBNFJpdNFQCwT2WKS2FPA","shape":"9, 8"},"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003esize=%{marker.size}\u003cbr\u003eavg_marks=%{marker.color}\u003cbr\u003esql_marks=%{customdata[1]}\u003cbr\u003eexcel_marks=%{customdata[2]}\u003cbr\u003epython_marks=%{customdata[3]}\u003cbr\u003epower_bi_marks=%{customdata[4]}\u003cbr\u003eenglish_marks=%{customdata[5]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Berlin","London","Los Angeles","Melbourne","New York","Paris","Sydney","Tokyo","Toronto"],"lat":{"dtype":"f8","bdata":"y2lPyTlCSkAqq+l6or5JQOHL6VffBkFAj\u002fV5MTnoQsBZOKSsOltEQIUvAhnwbUhAA5B\u002fC1fvQMDQuwxao9ZBQGoE0Uml00VA"},"legendgroup":"","lon":{"dtype":"f8","bdata":"MUfqmE7KKkCcN6nDZXDCvyulZ3qJj13AR0yaUNIeYkDZ0ZONYoBSwHgI46dxjwJAIIjiRKrmYkDPQkzTcXhhQCwT2WKS2FPA"},"marker":{"color":{"dtype":"f8","bdata":"UrgehesBVUCkcD0K12NVQEjhehSuJ1VAhetRuB5FVUB7FK5H4VpVQPYoXI\u002fCJVVACtejcD1KVUCPwvUoXF9VQD0K16NwLVVA"},"coloraxis":"coloraxis","size":{"dtype":"i1","bdata":"Dw8PDw8PDw8P"},"sizemode":"area","sizeref":0.0375,"symbol":"circle"},"mode":"markers","name":"","showlegend":false,"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outline ...
