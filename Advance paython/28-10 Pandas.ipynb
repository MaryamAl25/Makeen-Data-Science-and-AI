# %%
from pandas import Series
import pandas as pd

ww2_dict = {'USSR': 8700000, 'Germany': 4300000, 'China': 3000000, 'Japan': 2100000, 'USA': 400000}
WW2_Series = Series(ww2_dict)
#print(WW2_Series)

countries = ['China','Germany','Japan','USA','USSR','Argentina', 'Oman']
obj2 = Series(ww2_dict, index=countries)
print(obj2)
# Out:
# China        3000000.0
# Germany      4300000.0
# Japan        2100000.0
# USA           400000.0
# USSR         8700000.0
# Argentina          NaN
# Oman               NaN
# dtype: float64

# %%
#Exercise: Give me the countries that are not null as Series
condetion = obj2.notnull() #bollen series
obj2[condetion]
# Out:
# China      3000000.0
# Germany    4300000.0
# Japan      2100000.0
# USA         400000.0
# USSR       8700000.0
# dtype: float64

# %%
obj2[obj2.isnull()]
# Out:
# Series([], dtype: float64)

# %%
data = {
    "Names" : ["Fatama", "Sahab","Maryam"],
    "Ages" : [24,25,24],
    "City" : ["Salalah","Marbat","Saada"]
}
data
# Out:
# {'Names': ['Fatama', 'Sahab', 'Maryam'],
#  'Ages': [24, 25, 24],
#  'City': ['Salalah', 'Marbat', 'Saada']}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Names  Ages     City
# 0  Fatama    24  Salalah
# 1   Sahab    25   Marbat
# 2  Maryam    24    Saada

# %%
df.index = ["student 1","student 2","student 3"]
df
# Out:
#             Names  Ages     City
# student 1  Fatama    24  Salalah
# student 2   Sahab    25   Marbat
# student 3  Maryam    24    Saada

# %%
df.index = ["s1","s2","s3"]
df.rename = ["s1","s2","s3"]

# %%
df.replace = ["s1","s2","s3"]
df
# Out:
#      Names  Ages     City
# s1  Fatama    24  Salalah
# s2   Sahab    25   Marbat
# s3  Maryam    24    Saada

# %%
#rename
df = pd.DataFrame(data)
df =  df.rename(index={0: 'student 1', 1: 'student 2', 2:'student 3'})
print(df)

# %%
df.loc["student 1"] #get rows and columns by lebels
# Out:
# Names     Fatama
# Ages          24
# City     Salalah
# Name: student 1, dtype: object

# %%
df.iloc[0] #by position
# Out:
# Names     Fatama
# Ages          24
# City     Salalah
# Name: s1, dtype: object

# %%
df.loc["s1"] #by lebels
# Out:
# Names     Fatama
# Ages          24
# City     Salalah
# Name: s1, dtype: object
